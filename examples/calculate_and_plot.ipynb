# %% [markdown]
# Run the calculator on a radiograph from the publically available OAI database and plot the results

# %%
import pandas as pd
import os
import sys
sys.path.append('/research/projects/m303645_Anish/Current/')

import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)

# %%
from hip_mjsw.src.mJSW_calc import mJSWCalculator

val_dir = '/mnt/Annotations/mJSW_LGB-SS/OAI validation/'
val_files = [val_dir+f for f in os.listdir(val_dir) if f.endswith('.dcm')]

calculator = mJSWCalculator()

# %%
calculator.calculate(val_files[0], plot=True)
# Out:
# 100%|██████████| 1/1 [00:01<00:00,  1.28s/it]
# {'Left mJSW': 4.57, 'Right mJSW': 4.42}
